# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
x = [1,2,3,4]
y = [10 , 30  , 20 , 40]
plt.plot(x , y)
plt.savefig("./Output/fig.png")
plt.show()

# %%
day = ["sat" , "sun" , "mon" , "teu" , "wed" , "thur" , "fri"]
temp = [23, 14, 17 , 18 , 21 , 16 , 24]
plt.plot(day , temp , marker = "o" , linestyle = "--" , color = "blue")
plt.title("temp_day")
plt.xlabel ("day")
plt.ylabel("temp")
plt.grid()

# %%
classes = ["ai" , "network" , "mobile"]
students = [21 , 35, 47]
plt.bar(classes , students , color = "red")
plt.title("class size")
plt.xlabel("courses")
plt.ylabel("number of students")
# Out:
# Text(0, 0.5, 'number of students')

# %%
np.random.seed(42)
grade = np.random.normal(15 , 3 , 200)
plt.hist(grade , bins=  20 , color="green")
plt.title("grade dist")
plt.xlabel("grades")
plt.ylabel("frequents")
# Out:
# Text(0, 0.5, 'frequents')

# %%
labels = ["SVM" , "Decision Tree" , "logistic" , "KNN"]
sizes = [20 , 30 , 25 , 25]
plt.pie(sizes , labels=labels)
plt.title("model usage")
plt.axis("equal")
plt.show()

# %%
epochs = [0 , 1, 2, 3, 4]
model1 = [0.6 , 0.7 , 0.75 , 0.8 , 0.86]
model2 = [0.5 , 0.6 , 0.7 , 0.5 , 0.8]

plt.subplot(1,2,1)
plt.plot(epochs , model1 , marker = "o")
plt.title("loss of models")

plt.subplot(1,2,2)
plt.plot(epochs , model2 , marker = "x")
plt.title("loss of models")
# Out:
# Text(0.5, 1.0, 'loss of models')

# %%
df = pd.read_csv("./iris.csv")
data = pd.DataFrame(df)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa = data[data["species"]== "setosa"]["petal_length"]
versicolor = data[data["species"]== "versicolor"]["petal_length"]
virginica = data[data["species"]== "virginica"]["petal_length"]


plt.hist(setosa, bins=15, alpha=0.5, label='Setosa')
plt.hist(versicolor, bins=15, alpha=0.5, label='Versicolor')
plt.hist(virginica, bins=15, alpha=0.5, label='Virginica')

plt.title("Petal Length Distribution by Species")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
means = df.groupby('species')['petal_length'].mean()

plt.figure()
plt.plot(means.index, means.values, marker='o')
plt.title("Mean Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Mean Petal Length")
plt.grid(True)
plt.show()

# %%
plt.bar(means.index, means.values)
plt.title("Average Petal Length per Species")
plt.xlabel("Species")
plt.ylabel("Mean Petal Length")
plt.show()

# %%
for species in df['species'].unique():
    subset = df[df['species'] == species]
    plt.scatter(subset['petal_length'],
                subset['petal_length'],
                label=species)

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Petal Length vs Width")
plt.legend()
plt.show()

# %%
df.iloc[:, 0:4].hist(figsize=(10,8))
plt.suptitle("Histograms of All Features")
plt.show()
