# %%
import pandas as pd 
import numpy as np

# %%
data = {
    "sepal_length" :[5.1 , 2.3 , 3.6 , 7.8],
    "sepal_width" :[2,3,4,5],
    "petal_length" :[7,8,9,0],
    "petal_width" :[12,14,9,10],
    "species" :["s" ,"a" , "h" , 'q' ]
}

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1            2             7           12       s
# 1           2.3            3             8           14       a
# 2           3.6            4             9            9       h
# 3           7.8            5             0           10       q

# %%
df = pd.read_csv("iris.csv")
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
len(df)
# Out:
# 150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataframe.to_csv("./Output/iris_sample.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
X = df[["sepal_length" , "sepal_width" , "petal_length" ,"petal_width" ]]
Y = df ["species"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
X.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
virginica_df = df[df["species"] == "virginica"]

# %%
virginica_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
virginica_df = virginica_df[virginica_df["sepal_length"] > 6]

# %%
virginica_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 116           6.5          3.0           5.5          1.8  virginica
# ...

# %%
df.iloc[1]
# Out:
# sepal_length       4.9
# sepal_width        3.0
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 1, dtype: object

# %%
df.sort_values("sepal_length" , inplace= True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.loc[: ,"petal_length" ]
# Out:
# 13     1.1
# 8      1.4
# 42     1.3
# 38     1.3
# 41     1.3
#       ...
# 122    6.7
# 117    6.7
# 118    6.9
# 135    6.1
# 131    6.4
# Name: petal_length, Length: 150, dtype: float64

# %%
train_index = df.sample(frac=0.7 , random_state=42).index
train_dataset = df.loc[train_index]
test_dataset = df.loc[~df.index.isin(train_index)]

# %%
train_dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 14            5.8          4.0           1.2          0.2      setosa
# 34            4.9          3.1           1.5          0.2      setosa
# 104           6.5          3.0           5.8          2.2   virginica
# 92            5.8          2.6           4.0          1.2  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# ..            ...          ...           ...          ...         ...
# 38            4.4          3.0           1.3          0.2      setosa
# 37            4.9          3.6           1.4          0.1      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 120           6.9          3.2           5.7          2.3   virginica
#
# [105 rows x 5 columns]

# %%
#mini_project

# %%
dates = pd.date_range(start="2023-01-01" , end="2023-12-31" , freq="D")
data = {
    "date" : dates , 
    "sensor1" : np.random.normal(25 , 5, len(dates)),
    "sensor2" : np.random.normal(5,10 , len(dates)),
    "sensor3" : np.random.normal(15 , 3, len(dates))
    }
df = pd.DataFrame(data)
df.to_csv("sample_data.csv" , index=False)

# %%
df = pd.read_csv("sample_data.csv")
df["date"] = pd.to_datetime(df["date"])

# %%
np.random.seed(42)
mask = np.random.choice([True , False] , size=df[["sensor1" , "sensor2" , "sensor3"]].shape , p=[0.2 , 0.8])
df[["sensor1" , "sensor2" , "sensor3"]] = df[["sensor1" , "sensor2" , "sensor3"]].where(mask , np.nan)

# %%
df.set_index("date" , inplace=True)

# %%
jan_2023 = df.loc["2023-01-01" : "2023-01-31"]
sensor_above_25 = df.loc[df["sensor1"]>25]

# %%
jan_2023
# Out:
#               sensor1    sensor2    sensor3
# date
# 2023-01-01        NaN        NaN        NaN
# 2023-01-02        NaN -13.867815  12.884243
# 2023-01-03  30.785885        NaN        NaN
# 2023-01-04        NaN   8.886233        NaN
# 2023-01-05        NaN        NaN  10.638035
# 2023-01-06  23.723155        NaN        NaN
# 2023-01-07        NaN        NaN        NaN
# 2023-01-08  15.346483        NaN        NaN
# 2023-01-09        NaN        NaN   9.708289
# 2023-01-10        NaN        NaN  14.444412
# 2023-01-11        NaN  16.085790  19.101255
# 2023-01-12        NaN        NaN        NaN
# 2023-01-13        NaN -15.475182        NaN
# 2023-01-14        NaN  22.367184        NaN
# 2023-01-15  25.186575        NaN        NaN
# 2023-01-16        NaN        NaN        NaN
# 2023-01-17        NaN  16.289127        NaN
# 2023-01-18        NaN        NaN        NaN
# 2023-01-19        NaN        NaN  15.725978
# 2023-01-20  20.405781   5.429979        NaN
# ...

# %%
df_mean = df.copy()
df_mean["sensor1"] = df_mean["sensor1"].fillna(df_mean["sensor1"].mean())
df_mean["sensor2"] = df_mean["sensor2"].fillna(df_mean["sensor2"].mean())
df_mean["sensor3"] = df_mean["sensor3"].fillna(df_mean["sensor3"].mean())
